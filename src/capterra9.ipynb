# %%
import os
from selenium import webdriver
from selenium.webdriver.common.by import By
from tqdm import tqdm
from time import sleep

# SET the driver
chromedriver = "/usr/bin/chromedriver" # see Dockerfile for driver installation inside docker container c1
os.environ["webdriver.chrome.driver"] = chromedriver
options = webdriver.ChromeOptions()

chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--headless')
chrome_options.add_argument('--disable-gpu')
driver = webdriver.Chrome(options=chrome_options)

# %%
# from webdriver_manager.chrome import ChromeDriverManager
# driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
# GET the list of Software and the list of the corresponding websites
driver.get("https://www.capterra.fr/directory")
list_logiciels = driver.find_elements(By.CLASS_NAME, "list-group-item list-group-item-action border-0 fw-bold".replace(' ',"."))
logiciels = []
webIs = []
for el in list_logiciels:
    webI = el.get_attribute("href")
    webIs.append(webI)
    #logiciels.append(el.text)
driver.close()
print("Nlogiciels: ", len(webIs))
# Out:
# Nlogiciels:  983

# %%
start = 100
end = 125
webIs[start:end]
# Out:
# ['https://www.capterra.fr/directory/32458/food-truck-pos-systems/software',
#  'https://www.capterra.fr/directory/31656/retail-pos-system/software',
#  'https://www.capterra.fr/directory/30603/restaurant-pos/software',
#  'https://www.capterra.fr/directory/30915/ipad-pos/software',
#  'https://www.capterra.fr/directory/31307/remodeling-estimating/software',
#  'https://www.capterra.fr/directory/30753/takeoff/software',
#  'https://www.capterra.fr/directory/32297/calendar/software',
#  'https://www.capterra.fr/directory/31236/3d-cad/software',
#  'https://www.capterra.fr/directory/31237/architectural-cad/software',
#  'https://www.capterra.fr/directory/31816/directory/software',
#  'https://www.capterra.fr/directory/30916/logbook/software',
#  'https://www.capterra.fr/directory/31396/mind-mapping/software',
#  'https://www.capterra.fr/directory/30978/network-mapping/software',
#  'https://www.capterra.fr/directory/33716/data-catalog/software',
#  'https://www.capterra.fr/directory/30220/product-configurator/software',
#  'https://www.capterra.fr/directory/30007/call-center/software',
#  'https://www.capterra.fr/directory/31304/accreditation-management/software',
#  'https://www.capterra.fr/directory/10053/currency-exchange/software',
#  'https://www.capterra.fr/directory/30678/channel-management/software',
#  'https://www.capterra.fr/directory/31298/roofing/software',
#  'https://www.capterra.fr/directory/31260/dental-charting/software',
#  'https://www.capterra.fr/directory/30797/live-chat/software',
#  'https://www.capterra.fr/directory/32448/chatbot/software',
#  'https://www.capterra.fr/directory/31535/electrical-estimating/software',
#  'https://www.capterra.fr/directory/31517/plastic-surgery/software']

# %%
webIIs = []
for webI in tqdm(webIs[start:end]):
#webI = webIs[0]
#if (1==1):
    print(webI)
    driver = webdriver.Chrome(options=chrome_options)
    driver.get(webI)
    sleep(5)
    N5_1 = driver.find_elements(By.CLASS_NAME, "card product-card-new mb-3 border-seaglass pt-2".replace(' ',"."))
    sleep(2)
    for el in N5_1:
        try:   
            N5_2 = el.find_elements(By.CLASS_NAME, "col-sm-3".replace(' ',"."))
            sleep(2)
            Ncomments = int(str(N5_2[0].text).replace(u"\u202f", ""))
            if Ncomments>500:
                print(Ncomments)
                el_webI = el.find_elements(By.CLASS_NAME, "mos-star-rating d-inline-flex align-top flex-wrap column-gap-2 evnt fw-bold".replace(' ',"."))
                webIIs.append(el_webI[0].get_attribute("href") + '?countries[]=fr#facets')
                #webIIs.append(webI[0].get_attribute("href") )
        except:
           pass
    driver.close()
    #sleep(5)
print("----------------------------")
print(webIIs)
# Out:
#   0%|                                                                                                                       | 0/25 [00:00<?, ?it/s]
# https://www.capterra.fr/directory/32458/food-truck-pos-systems/software
#   4%|████▍                                                                                                          | 1/25 [00:08<03:24,  8.51s/it]
# https://www.capterra.fr/directory/31656/retail-pos-system/software
#   8%|████████▉                                                                                                      | 2/25 [00:17<03:19,  8.67s/it]
# https://www.capterra.fr/directory/30603/restaurant-pos/software
#  12%|█████████████▎                                                                                                 | 3/25 [00:26<03:11,  8.72s/it]
# https://www.capterra.fr/directory/30915/ipad-pos/software
# 540
# 2027
#  16%|█████████████████▊                                                                                             | 4/25 [01:21<09:30, 27.14s/it]
# https://www.capterra.fr/directory/31307/remodeling-estimating/software
#  20%|██████████████████████▏                                                                                        | 5/25 [01:29<06:46, 20.32s/it]
# https://www.capterra.fr/directory/30753/takeoff/software
# 1414
# 1004
# 799
# 697
#  24%|██████████████████████████▋                                                                                    | 6/25 [02:29<10:40, 33.69s/it]
# https://www.capterra.fr/directory/32297/calendar/software
# 2976
# 11449
# 9556
# 7225
# 5225
# 5107
# 4530
# 2610
# 2403
# 2466
# 1328
# 1261
# 1199
# 912
# 908
# 752
# 836
# 656
# 705
# 691
# 644
#  28%|███████████████████████████████                                                                                | 7/25 [03:29<12:42, 42.38s/it]
# 688
# https://www.capterra.fr/directory/31236/3d-cad/software
#  32%|███████████████████████████████████▌                                                                           | 8/25 [03:37<08:55, 31.53s/it]
# https://www.capterra.fr/directory/31237/architectural-cad/software
#  36%|███████████████████████████████████████▉                                                                       | 9/25 [03:46<06:29, 24.36s/it]
# https://www.capterra.fr/directory/31816/directory/software
# 506
#  40%|████████████████████████████████████████████                                                                  | 10/25 [04:27<07:22, 29.51s/it]
# https://www.capterra.fr/directory/30916/logbook/software
#  44%|████████████████████████████████████████████████▍                                                             | 11/25 [04:36<05:23, 23.10s/it]
# https://www.capterra.fr/directory/31396/mind-mapping/software
# 1847
# 1062
#  48%|████████████████████████████████████████████████████▊                                                         | 12/25 [05:35<07:24, 34.17s/it]
# https://www.capterra.fr/directory/30978/network-mapping/software
# 1847
# 1269
#  52%|█████████████████████████████████████████████████████████▏                                                    | 13/25 [06:34<08:20, 41.72s/it]
# https://www.capterra.fr/directory/33716/data-catalog/software
# 1365
#  56%|█████████████████████████████████████████████████████████████▌                                                | 14/25 [07:13<07:29, 40.88s/it]
# https://www.capterra.fr/directory/30220/product-configurator/software
# 593
#  60%|██████████████████████████████████████████████████████████████████                                            | 15/25 [08:13<07:44, 46.47s/it]
# https://www.capterra.fr/directory/30007/call-center/software
#  64%|██████████████████████████████████████████████████████████████████████▍                                       | 16/25 [08:22<05:17, 35.31s/it]
# https://www.capterra.fr/directory/31304/accreditation-management/software
#  68%|██████████████████████████████████████████████████████████████████████████▊                                   | 17/25 [09:03<04:55, 36.98s/it]
# https://www.capterra.fr/directory/10053/currency-exchange/software
#  72%|███████████████████████████████████████████████████████████████████████████████▏                              | 18/25 [09:56<04:52, 41.74s/it]
# https://www.capterra.fr/directory/30678/channel-management/software
# 634
# 534
#  76%|███████████████████████████████████████████████████████████████████████████████████▌                          | 19/25 [10:55<04:42, 47.08s/it]
# https://www.capterra.fr/directory/31298/roofing/software
#  80%|████████████████████████████████████████████████████████████████████████████████████████                      | 20/25 [11:04<02:57, 35.50s/it]
# https://www.capterra.fr/directory/31260/dental-charting/software
#  84%|████████████████████████████████████████████████████████████████████████████████████████████▍                 | 21/25 [12:01<02:48, 42.03s/it]
# https://www.capterra.fr/directory/30797/live-chat/software
# 2107
# 1255
# 1118
# 16534
# 11531
# 1876
# 1791
# 1150
# 673
# 502
#  88%|████████████████████████████████████████████████████████████████████████████████████████████████▊             | 22/25 [12:58<02:19, 46.64s/it]
# https://www.capterra.fr/directory/32448/chatbot/software
# 1791
# 932
# 673
# 502
#  92%|█████████████████████████████████████████████████████████████████████████████████████████████████████▏        | 23/25 [13:58<01:41, 50.51s/it]
# https://www.capterra.fr/directory/31535/electrical-estimating/software
#  96%|█████████████████████████████████████████████████████████████████████████████████████████████████████████▌    | 24/25 [14:06<00:37, 37.82s/it]
# https://www.capterra.fr/directory/31517/plastic-surgery/software
# 4530
# 2610
# 571
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 25/25 [15:03<00:00, 36.16s/it]
# ----------------------------
# ['https://www.capterra.fr/reviews/120491/lightspeed-retail?countries[]=fr#facets', 'https://www.capterra.fr/reviews/154907/square-point-of-sale?countries[]=fr#facets', 'https://www.capterra.fr/reviews/56250/procore?countries[]=fr#facets', 'https://www.capterra.fr/reviews/218046/autodesk-construction-cloud?countries[]=fr#facets', 'https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets', 'https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets', 'https://www.capterra.fr/reviews/147657/monday-com?countries[]=fr#facets', 'https://www.capterra.fr/reviews/168389/google-workspace?countries[]=fr#facets', 'https://www.capterra.fr/reviews/58688/microsoft-365?countries[]=fr#facets', 'https://www.capterra.fr/reviews/120550/asana-pm?countries[]=fr#facets', 'https://www.capterra.fr/reviews/169007/wix?countries[]=fr#facets', 'https://www.capterra.fr/reviews/148488/tsheets?countries[]=fr#facets', 'https://www.capterra.fr/reviews/128285/acuity-scheduling?countries[]=fr#facets', 'https://www.capterra.fr/reviews/153752/vagaro?countries[]=fr#facets', 'https://www.capterra.fr/reviews/148036/calendly?countries[]=fr#facets', 'https://www.capterra.fr/reviews/213340/google-calendar?countries[]=fr#facets', 'https://www.capterra.fr/reviews/40229/mindbody?countries[]=fr#facets', 'https://www.capterra.fr/reviews/76113/wrike?countries[]=fr#facets', 'https://www.capterra.fr/reviews/142620/doodle?countries[]=fr#facets', 'https://www.capterra.fr/reviews/136078/float?countries[]=fr#facets', 'https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets', 'https://www.capterra.fr/reviews/140086/simplybook-me?countries[]=fr#facets', 'https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets', 'https://www.capterra.fr/reviews/121248/when-i-work?countries[]=fr#facets', 'https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets', 'https://www.capterra.fr/reviews/122035/setmore?countries[]=fr#facets', 'https://www.capterra.fr/reviews/115536/findmyshift?countries[]=fr#facets', 'https://www.capterra.fr/reviews/1036086/goldie?countries[]=fr#facets', 'https://www.capterra.fr/reviews/133173/brilliant-directories?countries[]=fr#facets', 'https://www.capterra.fr/reviews/201133/visio?countries[]=fr#facets', 'https://www.capterra.fr/reviews/128955/miro?countries[]=fr#facets', 'https://www.capterra.fr/reviews/201133/visio?countries[]=fr#facets', 'https://www.capterra.fr/reviews/170983/google-cloud-platform?countries[]=fr#facets', 'https://www.capterra.fr/reviews/77260/tableau?countries[]=fr#facets', 'https://www.capterra.fr/reviews/211798/sketchup?countries[]=fr#facets', 'https://www.capterra.fr/reviews/152433/hostaway?countries[]=fr#facets', 'https://www.capterra.fr/reviews/131924/lodgify?countries[]=fr#facets', 'https://www.capterra.fr/reviews/164283/zendesk?countries[]=fr#facets', 'https://www.capterra.fr/reviews/169505/zoho-desk?countries[]=fr#facets', 'https://www.capterra.fr/reviews/102188/liveagent?countries[]=fr#facets', 'https://www.capterra.fr/reviews/135003/slack?countries[]=fr#facets', 'https://www.capterra.fr/reviews/180345/whatsapp?countries[]=fr#facets', 'https://www.capterra.fr/reviews/124981/freshdesk?countries[]=fr#facets', 'https://www.capterra.fr/reviews/132666/pipedrive?countries[]=fr#facets', 'https://www.capterra.fr/reviews/62194/livechat?countries[]=fr#facets', 'https://www.capterra.fr/reviews/134347/intercom?countries[]=fr#facets', 'https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets', 'https://www.capterra.fr/reviews/132666/pipedrive?countries[]=fr#facets', 'https://www.capterra.fr/reviews/140928/appy-pie?countries[]=fr#facets', 'https://www.capterra.fr/reviews/134347/intercom?countries[]=fr#facets', 'https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets', 'https://www.capterra.fr/reviews/128285/acuity-scheduling?countries[]=fr#facets', 'https://www.capterra.fr/reviews/153752/vagaro?countries[]=fr#facets', 'https://www.capterr ...

# %%
records = []
ind = 0
categories_pattern = "i18n-translation_container pt-4 py-3 py-md-5 review-card"
#i18n-translation_container pt-4 py-3 py-md-5 review-card 
categories_pattern = categories_pattern.replace(' ',".")

#driver = webdriver.Chrome(options=chrome_options)
for webII in tqdm(webIIs):
    print("webII: ", webII)
    driver = webdriver.Chrome(options=chrome_options)
    sleep(1)
    # driver.get(webII + '?countries[]=fr#facets')
    driver.get(webII)
    sleep(1)
    categories_list = driver.find_elements(By.CLASS_NAME,categories_pattern)
    try:
        el_pages = driver.find_elements(By.CLASS_NAME, "page-link".replace(' ',"."))
        l = len(el_pages)
        Npages = int(el_pages[l-2].text)
    except:
        Npages = 1
    print("Npages: ", Npages)
    #driver.quit()
    sleep(1)
    
    for page in range(Npages):
        #htt = webII + '?page=' + str(page+1) + '?countries[]=fr#facets'
        #htt = str(webII) + '?countries[]=fr#facets' + '?page=' + str(page+1) 
        htt = webII + '?page=' + str(page+1) 
        #htt = 'https://www.capterra.fr/reviews/163335/gotowebinar?countries[]=fr#facets?countries[]=fr#facets?page=1'
        print(htt)
        driver = webdriver.Chrome(options=chrome_options)
        sleep(1)
        driver.get(htt)
        sleep(1)
        categories_list = driver.find_elements(By.CLASS_NAME,categories_pattern)
        print("categories_list: ", len(categories_list) )
    
        for el in categories_list:
        #el = categories_list[2]
        #if (1==1):
            try:
                record = {}
                ind = ind + 1
                
                el_comment = el.find_elements(By.CLASS_NAME, "col-lg-7".replace(' ',"."))
                el_review_score = el.find_elements(By.CLASS_NAME, "ms-1")

                el_name1 = el.find_elements(By.CLASS_NAME, "col-lg-5 mb-3 mb-lg-0".replace(' ',"."))
                el_name2 = el_name1[0].find_elements(By.CLASS_NAME, "h5 fw-bold mb-2".replace(' ',".")) 
                #el_comments2 = el_comments[0].find_elements(By.XPATH, "//*[@class='col-lg-7']/p/span")

                el_date1 = el_comment[0].find_elements(By.CLASS_NAME, "ms-2".replace(' ',"."))

                el_title1 = el_comment[0].find_elements(By.CLASS_NAME, "h5 fw-bold".replace(' ',"."))

                el_duration2 = el_name1[0].find_elements(By.CLASS_NAME, "col-12 col-md-6 col-lg-12 pt-3 pt-md-0 pt-lg-3 text-ash".replace(' ',"."))
                el_duration3 = el_duration2[0].find_elements(By.CLASS_NAME, "mb-2".replace(' ',"."))
                #print(el_duration3)
                duration = ""
                for d in el_duration3:
                    if "Temps d'utilisation du logiciel" in d.text:
                        duration = d.text
    
                review_score = el_review_score[0].text
                comment = el_comment[0].text.split("Commentaires : ")
                #print(comment)
                #print("title:", el_title1[0].text)
                
                if (len(comment)>1):
                    comment = comment[1].split("\n")[0]
                    name = el_name2[0].text
                    the_date = el_date1[0].text
                    title = el_title1[0].text
                    #print("===============")
        
                    record["comment"] = comment
                    record['date_experience'] = duration
                    record['review_score'] = review_score
                    record['timestamp'] = the_date
                    record['title'] = title
                    record['user_name'] = name

                    records.append(record)
                #driver.close()
                sleep(1)
            except:
                ind = ind - 1
                pass
        print("len: ", len(records))
        driver.close()
        sleep(5)
# Out:
#   0%|                                                                                                                       | 0/54 [00:00<?, ?it/s]
# webII:  https://www.capterra.fr/reviews/120491/lightspeed-retail?countries[]=fr#facets
# Npages:  1
# https://www.capterra.fr/reviews/120491/lightspeed-retail?countries[]=fr#facets?page=1
# categories_list:  3
# len:  2
#   2%|██                                                                                                             | 1/54 [00:15<13:58, 15.82s/it]
# webII:  https://www.capterra.fr/reviews/154907/square-point-of-sale?countries[]=fr#facets
# Npages:  1
# https://www.capterra.fr/reviews/154907/square-point-of-sale?countries[]=fr#facets?page=1
# categories_list:  1
# len:  3
#   4%|████                                                                                                           | 2/54 [00:30<13:00, 15.02s/it]
# webII:  https://www.capterra.fr/reviews/56250/procore?countries[]=fr#facets
# Npages:  1
# https://www.capterra.fr/reviews/56250/procore?countries[]=fr#facets?page=1
# categories_list:  3
# len:  4
#   6%|██████▏                                                                                                        | 3/54 [00:46<13:25, 15.79s/it]
# webII:  https://www.capterra.fr/reviews/218046/autodesk-construction-cloud?countries[]=fr#facets
# Npages:  1
# https://www.capterra.fr/reviews/218046/autodesk-construction-cloud?countries[]=fr#facets?page=1
# categories_list:  9
# len:  9
#   7%|████████▏                                                                                                      | 4/54 [01:10<15:40, 18.81s/it]
# webII:  https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets
# Npages:  56
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=1
# categories_list:  25
# len:  26
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=2
# categories_list:  25
# len:  43
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=3
# categories_list:  25
# len:  60
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=4
# categories_list:  25
# len:  77
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=5
# categories_list:  25
# len:  94
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=6
# categories_list:  25
# len:  111
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=7
# categories_list:  25
# len:  128
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=8
# categories_list:  25
# len:  145
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=9
# categories_list:  25
# len:  162
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=10
# categories_list:  25
# len:  179
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=11
# categories_list:  25
# len:  196
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=12
# categories_list:  25
# len:  213
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=13
# categories_list:  25
# len:  230
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=14
# categories_list:  25
# len:  247
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=15
# categories_list:  25
# len:  264
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=16
# categories_list:  25
# len:  281
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=17
# categories_list:  25
# len:  298
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=18
# categories_list:  25
# len:  315
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=19
# categories_list:  25
# len:  332
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=20
# categories_list:  25
# len:  349
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=21
# categories_list:  25
# len:  366
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=22
# categories_list:  25
# len:  383
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=23
# categories_list:  25
# len:  400
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=24
# categories_list:  25
# len:  417
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=25
# categories_list:  25
# len:  434
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=26
# categories_list:  25
# len:  451
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=27
# categories_list:  25
# len:  468
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=28
# categories_list:  25
# len:  485
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=29
# categories_list:  25
# len:  502
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=30
# categories_list:  25
# len:  519
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=31
# categories_list:  25
# len:  536
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=32
# categories_list:  25
# len:  553
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=33
# categories_list:  25
# len:  570
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=34
# categories_list:  25
# len:  587
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=35
# categories_list:  25
# len:  604
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=36
# categories_list:  25
# len:  621
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=37
# categories_list:  25
# len:  638
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=38
# categories_list:  25
# len:  655
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=39
# categories_list:  25
# len:  672
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=40
# categories_list:  25
# len:  689
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=41
# categories_list:  25
# len:  706
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=42
# categories_list:  25
# len:  723
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=43
# categories_list:  25
# len:  740
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=44
# categories_list:  25
# len:  757
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=45
# categories_list:  25
# len:  774
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=46
# categories_list:  25
# len:  791
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=47
# categories_list:  25
# len:  808
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=48
# categories_list:  25
# len:  825
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=49
# categories_list:  25
# len:  842
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=50
# categories_list:  25
# len:  859
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=51
# categories_list:  25
# len:  876
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=52
# categories_list:  25
# len:  893
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=53
# categories_list:  25
# len:  910
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=54
# categories_list:  25
# len:  927
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=55
# categories_list:  25
# len:  944
# https://www.capterra.fr/reviews/147181/stack-takeoff?countries[]=fr#facets?page=56
# categories_list:  25
# len:  961
#   9%|█████████▉                                                                                                 | 5/54 [35:50<10:22:31, 762.27s/it]
# webII:  https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets
# Npages:  38
# https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets?page=1
# categories_list:  25
# len:  979
# https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets?page=2
# categories_list:  25
# len:  997
# https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets?page=3
# categories_list:  25
# len:  1015
# https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets?page=4
# categories_list:  25
# len:  1033
# https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets?page=5
# categories_list:  25
# len:  1051
# https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets?page=6
# categories_list:  25
# len:  1069
# https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets?page=7
# categories_list:  25
# len:  1087
# https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets?page=8
# categories_list:  25
# len:  1105
# https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets?page=9
# categories_list:  25
# len:  1123
# https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets?page=10
# categories_list:  25
# len:  1141
# https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets?page=11
# categories_list:  25
# len:  1159
# https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets?page=12
# categories_list:  25
# len:  1177
# https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets?page=13
# categories_list:  25
# len:  1195
# https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets?page=14
# categories_list:  25
# len:  1213
# https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets?page=15
# categories_list:  25
# len:  1231
# https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets?page=16
# categories_list:  25
# len:  1249
# https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets?page=17
# categories_list:  25
# len:  1267
# https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets?page=18
# categories_list:  25
# len:  1285
# https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets?page=19
# categories_list:  25
# len:  1303
# https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets?page=20
# categories_list:  25
# len:  1321
# https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets?page=21
# categories_list:  25
# len:  1339
# https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets?page=22
# categories_list:  25
# len:  1357
# https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets?page=23
# categories_list:  25
# len:  1375
# https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets?page=24
# categories_list:  25
# len:  1393
# https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets?page=25
# categories_list:  25
# len:  1411
# https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets?page=26
# categories_list:  25
# len:  1429
# https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets?page=27
# categories_list:  25
# len:  1447
# https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets?page=28
# categories_list:  25
# len:  1465
# https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets?page=29
# categories_list:  25
# len:  1483
# https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets?page=30
# categories_list:  25
# len:  1501
# https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets?page=31
# categories_list:  25
# len:  1519
# https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets?page=32
# categories_list:  25
# len:  1537
# https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets?page=33
# categories_list:  25
# len:  1555
# https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets?page=34
# categories_list:  25
# len:  1573
# https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets?page=35
# categories_list:  25
# len:  1591
# https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets?page=36
# categories_list:  25
# len:  1609
# https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets?page=37
# categories_list:  25
# len:  1627
# https://www.capterra.fr/reviews/121586/bluebeam-pdf-revu?countries[]=fr#facets?page=38
# categories_list:  25
# len:  1645
#  11%|███████████▉                                                                                               | 6/54 [59:17<13:05:04, 981.35s/it]
# webII:  https://www.capterra.fr/reviews/147657/monday-com?countries[]=fr#facets
# Npages:  4
# https://www.capterra.fr/reviews/147657/monday-com?countries[]=fr#facets?page=1
# categories_list:  25
# len:  1654
# https://www.capterra.fr/reviews/147657/monday-com?countries[]=fr#facets?page=2
# categories_list:  25
# len:  1663
# https://www.capterra.fr/reviews/147657/monday-com?countries[]=fr#facets?page=3
# categories_list:  25
# len:  1672
# https://www.capterra.fr/reviews/147657/monday-com?countries[]=fr#facets?page=4
# categories_list:  25
# len:  1681
#  13%|█████████████▋                                                                                            | 7/54 [1:01:49<9:16:14, 710.09s/it]
# webII:  https://www.capterra.fr/reviews/168389/google-workspace?countries[]=fr#facets
# Npages:  5
# https://www.capterra.fr/reviews/168389/google-workspace?countries[]=fr#facets?page=1
# categories_list:  25
# len:  1697
# https://www.capterra.fr/reviews/168389/google-workspace?countries[]=fr#facets?page=2
# categories_list:  25
# len:  1713
# https://www.capterra.fr/reviews/168389/google-workspace?countries[]=fr#facets?page=3
# categories_list:  25
# len:  1729
# https://www.capterra.fr/reviews/168389/google-workspace?countries[]=fr#facets?page=4
# categories_list:  25
# len:  1745
# https://www.capterra.fr/reviews/168389/google-workspace?countries[]=fr#facets?page=5
# categories_list:  25
# len:  1761
#  15%|███████████████▋                                                                                          | 8/54 [1:04:58<6:57:13, 544.21s/it]
# webII:  https://www.capterra.fr/reviews/58688/microsoft-365?countries[]=fr#facets
# Npages:  4
# https://www.capterra.fr/reviews/58688/microsoft-365?countries[]=fr#facets?page=1
# categories_list:  25
# len:  1773
# https://www.capterra.fr/reviews/58688/microsoft-365?countries[]=fr#facets?page=2
# categories_list:  25
# len:  1785
# https://www.capterra.fr/reviews/58688/microsoft-365?countries[]=fr#facets?page=3
# categories_list:  25
# len:  1797
# https://www.capterra.fr/reviews/58688/microsoft-365?countries[]=fr#facets?page=4
# categories_list:  25
# len:  1809
#  17%|█████████████████▋                                                                                        | 9/54 [1:07:29<5:16:01, 421.37s/it]
# webII:  https://www.capterra.fr/reviews/120550/asana-pm?countries[]=fr#facets
# Npages:  4
# https://www.capterra.fr/reviews/120550/asana-pm?countries[]=fr#facets?page=1
# categories_list:  25
# len:  1819
# https://www.capterra.fr/reviews/120550/asana-pm?countries[]=fr#facets?page=2
# categories_list:  25
# len:  1829
# https://www.capterra.fr/reviews/120550/asana-pm?countries[]=fr#facets?page=3
# categories_list:  25
# len:  1839
# https://www.capterra.fr/reviews/120550/asana-pm?countries[]=fr#facets?page=4
# categories_list:  25
# len:  1849
#  19%|███████████████████▍                                                                                     | 10/54 [1:10:00<4:07:47, 337.90s/it]
# webII:  https://www.capterra.fr/reviews/169007/wix?countries[]=fr#facets
# Npages:  4
# https://www.capterra.fr/reviews/169007/wix?countries[]=fr#facets?page=1
# categories_list:  25
# len:  1865
# https://www.capterra.fr/reviews/169007/wix?countries[]=fr#facets?page=2
# categories_list:  25
# len:  1881
# https://www.capterra.fr/reviews/169007/wix?countries[]=fr#facets?page=3
# categories_list:  25
# len:  1897
# https://www.capterra.fr/reviews/169007/wix?countries[]=fr#facets?page=4
# categories_list:  25
# len:  1913
#  20%|█████████████████████▍                                                                                   | 11/54 [1:12:32<3:21:27, 281.11s/it]
# webII:  https://www.capterra.fr/reviews/148488/tsheets?countries[]=fr#facets
# Npages:  1
# https://www.capterra.fr/reviews/148488/tsheets?countries[]=fr#facets?page=1
# categories_list:  13
# len:  1917
#  22%|███████████████████████▎                                                                                 | 12/54 [1:13:00<2:22:48, 204.02s/it]
# webII:  https://www.capterra.fr/reviews/128285/acuity-scheduling?countries[]=fr#facets
# Npages:  1
# https://www.capterra.fr/reviews/128285/acuity-scheduling?countries[]=fr#facets?page=1
# categories_list:  24
# len:  1929
#  24%|█████████████████████████▎                                                                               | 13/54 [1:13:40<1:45:31, 154.43s/it]
# webII:  https://www.capterra.fr/reviews/153752/vagaro?countries[]=fr#facets
# Npages:  1
# https://www.capterra.fr/reviews/153752/vagaro?countries[]=fr#facets?page=1
# categories_list:  2
# len:  1930
#  26%|███████████████████████████▏                                                                             | 14/54 [1:13:56<1:14:58, 112.46s/it]
# webII:  https://www.capterra.fr/reviews/148036/calendly?countries[]=fr#facets
# Npages:  3
# https://www.capterra.fr/reviews/148036/calendly?countries[]=fr#facets?page=1
# categories_list:  25
# len:  1941
# https://www.capterra.fr/reviews/148036/calendly?countries[]=fr#facets?page=2
# categories_list:  25
# len:  1952
# https://www.capterra.fr/reviews/148036/calendly?countries[]=fr#facets?page=3
# categories_list:  25
# len:  1963
#  28%|█████████████████████████████▏                                                                           | 15/54 [1:15:52<1:13:44, 113.44s/it]
# webII:  https://www.capterra.fr/reviews/213340/google-calendar?countries[]=fr#facets
# Npages:  3
# https://www.capterra.fr/reviews/213340/google-calendar?countries[]=fr#facets?page=1
# categories_list:  25
# len:  1977
# https://www.capterra.fr/reviews/213340/google-calendar?countries[]=fr#facets?page=2
# categories_list:  25
# len:  1991
# https://www.capterra.fr/reviews/213340/google-calendar?countries[]=fr#facets?page=3
# categories_list:  25
# len:  2005
#  30%|███████████████████████████████                                                                          | 16/54 [1:17:47<1:12:10, 113.97s/it]
# webII:  https://www.capterra.fr/reviews/40229/mindbody?countries[]=fr#facets
# Npages:  1
# https://www.capterra.fr/reviews/40229/mindbody?countries[]=fr#facets?page=1
# categories_list:  7
# len:  2010
#  31%|██████████████████████████████████                                                                          | 17/54 [1:18:08<53:06, 86.11s/it]
# webII:  https://www.capterra.fr/reviews/76113/wrike?countries[]=fr#facets
# Npages:  2
# https://www.capterra.fr/reviews/76113/wrike?countries[]=fr#facets?page=1
# categories_list:  25
# len:  2023
# https://www.capterra.fr/reviews/76113/wrike?countries[]=fr#facets?page=2
# categories_list:  25
# len:  2036
#  33%|████████████████████████████████████                                                                        | 18/54 [1:19:26<50:16, 83.79s/it]
# webII:  https://www.capterra.fr/reviews/142620/doodle?countries[]=fr#facets
# Npages:  4
# https://www.capterra.fr/reviews/142620/doodle?countries[]=fr#facets?page=1
# categories_list:  25
# len:  2051
# https://www.capterra.fr/reviews/142620/doodle?countries[]=fr#facets?page=2
# categories_list:  25
# len:  2066
# https://www.capterra.fr/reviews/142620/doodle?countries[]=fr#facets?page=3
# categories_list:  25
# len:  2081
# https://www.capterra.fr/reviews/142620/doodle?countries[]=fr#facets?page=4
# categories_list:  25
# len:  2096
#  35%|████████████████████████████████████▉                                                                    | 19/54 [1:21:59<1:00:51, 104.32s/it]
# webII:  https://www.capterra.fr/reviews/136078/float?countries[]=fr#facets
# Npages:  2
# https://www.capterra.fr/reviews/136078/float?countries[]=fr#facets?page=1
# categories_list:  25
# len:  2108
# https://www.capterra.fr/reviews/136078/float?countries[]=fr#facets?page=2
# categories_list:  25
# len:  2120
#  37%|████████████████████████████████████████                                                                    | 20/54 [1:23:17<54:47, 96.68s/it]
# webII:  https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets
# Npages:  53
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=1
# categories_list:  25
# len:  2130
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=2
# categories_list:  25
# len:  2140
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=3
# categories_list:  25
# len:  2150
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=4
# categories_list:  25
# len:  2160
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=5
# categories_list:  25
# len:  2170
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=6
# There was an error managing chrome (error sending request for url (https://googlechromelabs.github.io/chrome-for-testing/known-good-versions-with-downloads.json): error trying to connect: dns error: failed to lookup address information: Try again); using driver found in the cache
# categories_list:  25
# len:  2180
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=7
# categories_list:  25
# len:  2190
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=8
# categories_list:  25
# len:  2200
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=9
# categories_list:  25
# len:  2210
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=10
# categories_list:  25
# len:  2220
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=11
# categories_list:  25
# len:  2230
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=12
# categories_list:  25
# len:  2240
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=13
# categories_list:  25
# len:  2250
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=14
# categories_list:  25
# len:  2260
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=15
# categories_list:  25
# len:  2270
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=16
# categories_list:  25
# len:  2280
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=17
# categories_list:  25
# len:  2290
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=18
# categories_list:  25
# len:  2300
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=19
# categories_list:  25
# len:  2310
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=20
# categories_list:  25
# len:  2320
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=21
# categories_list:  25
# len:  2330
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=22
# categories_list:  25
# len:  2340
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=23
# categories_list:  25
# len:  2350
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=24
# categories_list:  25
# len:  2360
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=25
# categories_list:  25
# len:  2370
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=26
# categories_list:  25
# len:  2380
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=27
# categories_list:  25
# len:  2390
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=28
# categories_list:  25
# len:  2400
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=29
# categories_list:  25
# len:  2410
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=30
# categories_list:  25
# len:  2420
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=31
# categories_list:  25
# len:  2430
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=32
# categories_list:  25
# len:  2440
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=33
# categories_list:  25
# len:  2450
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=34
# categories_list:  25
# len:  2460
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=35
# categories_list:  25
# len:  2470
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=36
# categories_list:  25
# len:  2480
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=37
# categories_list:  25
# len:  2490
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=38
# categories_list:  25
# len:  2500
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=39
# categories_list:  25
# len:  2510
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=40
# categories_list:  25
# len:  2520
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=41
# categories_list:  25
# len:  2530
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=42
# categories_list:  25
# len:  2540
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=43
# categories_list:  25
# len:  2550
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=44
# categories_list:  25
# len:  2560
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=45
# categories_list:  25
# len:  2570
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=46
# categories_list:  25
# len:  2580
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=47
# categories_list:  25
# len:  2590
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=48
# categories_list:  25
# len:  2600
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=49
# categories_list:  25
# len:  2610
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=50
# categories_list:  25
# len:  2620
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=51
# categories_list:  25
# len:  2630
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=52
# categories_list:  25
# len:  2640
# https://www.capterra.fr/reviews/145635/upkeep?countries[]=fr#facets?page=53
# categories_list:  25
# len:  2650
#  39%|████████████████████████████████████████▊                                                                | 21/54 [1:55:59<6:01:00, 656.38s/it]
# webII:  https://www.capterra.fr/reviews/140086/simplybook-me?countries[]=fr#facets
# Npages:  4
# https://www.capterra.fr/reviews/140086/simplybook-me?countries[]=fr#facets?page=1
# categories_list:  25
# len:  2668
# https://www.capterra.fr/reviews/140086/simplybook-me?countries[]=fr#facets?page=2
# categories_list:  25
# len:  2686
# https://www.capterra.fr/reviews/140086/simplybook-me?countries[]=fr#facets?page=3
# categories_list:  25
# len:  2704
# https://www.capterra.fr/reviews/140086/simplybook-me?countries[]=fr#facets?page=4
# categories_list:  25
# len:  2722
#  41%|██████████████████████████████████████████▊                                                              | 22/54 [1:58:32<4:29:34, 505.44s/it]
# webII:  https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets
# Npages:  46
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=1
# categories_list:  25
# len:  2742
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=2
# categories_list:  25
# len:  2762
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=3
# categories_list:  25
# len:  2782
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=4
# categories_list:  25
# len:  2802
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=5
# categories_list:  25
# len:  2822
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=6
# categories_list:  25
# len:  2842
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=7
# categories_list:  25
# len:  2862
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=8
# categories_list:  25
# len:  2882
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=9
# categories_list:  25
# len:  2902
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=10
# categories_list:  25
# len:  2922
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=11
# categories_list:  25
# len:  2942
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=12
# categories_list:  25
# len:  2962
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=13
# categories_list:  25
# len:  2982
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=14
# categories_list:  25
# len:  3002
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=15
# categories_list:  25
# len:  3022
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=16
# categories_list:  25
# len:  3042
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=17
# categories_list:  25
# len:  3062
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=18
# categories_list:  25
# len:  3082
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=19
# categories_list:  25
# len:  3102
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=20
# categories_list:  25
# len:  3122
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=21
# categories_list:  25
# len:  3142
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=22
# categories_list:  25
# len:  3162
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=23
# categories_list:  25
# len:  3182
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=24
# categories_list:  25
# len:  3202
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=25
# categories_list:  25
# len:  3222
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=26
# categories_list:  25
# len:  3242
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=27
# categories_list:  25
# len:  3262
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=28
# categories_list:  25
# len:  3282
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=29
# categories_list:  25
# len:  3302
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=30
# categories_list:  25
# len:  3322
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=31
# categories_list:  25
# len:  3342
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=32
# categories_list:  25
# len:  3362
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=33
# categories_list:  25
# len:  3382
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=34
# categories_list:  25
# len:  3402
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=35
# categories_list:  25
# len:  3422
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=36
# categories_list:  25
# len:  3442
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=37
# categories_list:  25
# len:  3462
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=38
# categories_list:  25
# len:  3482
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=39
# categories_list:  25
# len:  3502
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=40
# categories_list:  25
# len:  3522
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=41
# categories_list:  25
# len:  3542
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=42
# categories_list:  25
# len:  3562
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=43
# categories_list:  25
# len:  3582
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=44
# categories_list:  25
# len:  3602
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=45
# categories_list:  25
# len:  3622
# https://www.capterra.fr/reviews/123038/7shifts-restaurant-scheduling?countries[]=fr#facets?page=46
# categories_list:  25
# len:  3642
#  43%|████████████████████████████████████████████▋                                                            | 23/54 [2:27:07<7:28:40, 868.41s/it]
# webII:  https://www.capterra.fr/reviews/121248/when-i-work?countries[]=fr#facets
# Npages:  1
# https://www.capterra.fr/reviews/121248/when-i-work?countries[]=fr#facets?page=1
# categories_list:  2
# len:  3644
#  44%|██████████████████████████████████████████████▋                                                          | 24/54 [2:27:23<5:06:16, 612.55s/it]
# webII:  https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets
# Npages:  39
# https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets?page=1
# categories_list:  25
# len:  3660
# https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets?page=2
# categories_list:  25
# len:  3676
# https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets?page=3
# categories_list:  25
# len:  3692
# https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets?page=4
# categories_list:  25
# len:  3708
# https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets?page=5
# categories_list:  25
# len:  3724
# https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets?page=6
# categories_list:  25
# len:  3740
# https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets?page=7
# categories_list:  25
# len:  3756
# https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets?page=8
# categories_list:  25
# len:  3772
# https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets?page=9
# categories_list:  25
# len:  3788
# https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets?page=10
# categories_list:  25
# len:  3804
# https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets?page=11
# categories_list:  25
# len:  3820
# https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets?page=12
# categories_list:  25
# len:  3836
# https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets?page=13
# categories_list:  25
# len:  3852
# https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets?page=14
# categories_list:  25
# len:  3868
# https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets?page=15
# categories_list:  25
# len:  3884
# https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets?page=16
# categories_list:  25
# len:  3900
# https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets?page=17
# categories_list:  25
# len:  3916
# https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets?page=18
# categories_list:  25
# len:  3932
# https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets?page=19
# categories_list:  25
# len:  3948
# https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets?page=20
# categories_list:  25
# len:  3964
# https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets?page=21
# categories_list:  25
# len:  3980
# https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets?page=22
# categories_list:  25
# len:  3996
# https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets?page=23
# categories_list:  25
# len:  4012
# https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets?page=24
# categories_list:  25
# len:  4028
# https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets?page=25
# categories_list:  25
# len:  4044
# https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets?page=26
# categories_list:  25
# len:  4060
# https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets?page=27
# categories_list:  25
# len:  4076
# https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets?page=28
# categories_list:  25
# len:  4092
# https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets?page=29
# categories_list:  25
# len:  4108
# https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets?page=30
# categories_list:  25
# len:  4124
# https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets?page=31
# categories_list:  25
# len:  4140
# https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets?page=32
# categories_list:  25
# len:  4156
# https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets?page=33
# categories_list:  25
# len:  4172
# https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets?page=34
# categories_list:  25
# len:  4188
# https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets?page=35
# categories_list:  25
# len:  4204
# https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets?page=36
# categories_list:  25
# len:  4220
# https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets?page=37
# categories_list:  25
# len:  4236
# https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets?page=38
# categories_list:  25
# len:  4252
# https://www.capterra.fr/reviews/153076/homebase?countries[]=fr#facets?page=39
# categories_list:  25
# len:  4268
#  46%|████████████████████████████████████████████████▌                                                        | 25/54 [2:51:42<6:58:45, 866.41s/it]
# webII:  https://www.capterra.fr/reviews/122035/setmore?countries[]=fr#facets
# Npages:  1
# https://www.capterra.fr/reviews/122035/setmore?countries[]=fr#facets?page=1
# categories_list:  6
# len:  4270
#  48%|██████████████████████████████████████████████████▌                                                      | 26/54 [2:52:02<4:45:48, 612.45s/it]
# webII:  https://www.capterra.fr/reviews/115536/findmyshift?countries[]=fr#facets
# Npages:  1
# https://www.capterra.fr/reviews/115536/findmyshift?countries[]=fr#facets?page=1
# categories_list:  7
# len:  4274
#  50%|████████████████████████████████████████████████████▌                                                    | 27/54 [2:52:23<3:15:47, 435.10s/it]
# webII:  https://www.capterra.fr/reviews/1036086/goldie?countries[]=fr#facets
# Npages:  1
# https://www.capterra.fr/reviews/1036086/goldie?countries[]=fr#facets?page=1
# categories_list:  1
# len:  4275
#  52%|██████████████████████████████████████████████████████▍                                                  | 28/54 [2:52:37<2:13:50, 308.88s/it]
# webII:  https://www.capterra.fr/reviews/133173/brilliant-directories?countries[]=fr#facets
# Npages:  1
# https://www.capterra.fr/reviews/133173/brilliant-directories?countries[]=fr#facets?page=1
# categories_list:  2
# len:  4275
#  54%|████████████████████████████████████████████████████████▍                                                | 29/54 [2:52:53<1:32:01, 220.85s/it]
# webII:  https://www.capterra.fr/reviews/201133/visio?countries[]=fr#facets
# Npages:  1
# https://www.capterra.fr/reviews/201133/visio?countries[]=fr#facets?page=1
# categories_list:  22
# len:  4287
#  56%|██████████████████████████████████████████████████████████▎                                              | 30/54 [2:53:31<1:06:24, 166.01s/it]
# webII:  https://www.capterra.fr/reviews/128955/miro?countries[]=fr#facets
# Npages:  3
# https://www.capterra.fr/reviews/128955/miro?countries[]=fr#facets?page=1
# categories_list:  25
# len:  4295
# https://www.capterra.fr/reviews/128955/miro?countries[]=fr#facets?page=2
# categories_list:  25
# len:  4303
# https://www.capterra.fr/reviews/128955/miro?countries[]=fr#facets?page=3
# categories_list:  25
# len:  4311
#  57%|█████████████████████████████████████████████████████████████▍                                             | 31/54 [2:55:26<57:47, 150.76s/it]
# webII:  https://www.capterra.fr/reviews/201133/visio?countries[]=fr#facets
# Npages:  1
# https://www.capterra.fr/reviews/201133/visio?countries[]=fr#facets?page=1
# categories_list:  22
# len:  4323
#  59%|███████████████████████████████████████████████████████████████▍                                           | 32/54 [2:56:04<42:54, 117.01s/it]
# webII:  https://www.capterra.fr/reviews/170983/google-cloud-platform?countries[]=fr#facets
# Npages:  2
# https://www.capterra.fr/reviews/170983/google-cloud-platform?countries[]=fr#facets?page=1
# categories_list:  25
# len:  4338
# https://www.capterra.fr/reviews/170983/google-cloud-platform?countries[]=fr#facets?page=2
# categories_list:  25
# len:  4353
#  61%|█████████████████████████████████████████████████████████████████▍                                         | 33/54 [2:57:22<36:52, 105.36s/it]
# webII:  https://www.capterra.fr/reviews/77260/tableau?countries[]=fr#facets
# Npages:  1
# https://www.capterra.fr/reviews/77260/tableau?countries[]=fr#facets?page=1
# categories_list:  23
# len:  4366
#  63%|████████████████████████████████████████████████████████████████████                                        | 34/54 [2:58:01<28:29, 85.49s/it]
# webII:  https://www.capterra.fr/reviews/211798/sketchup?countries[]=fr#facets
# Npages:  1
# https://www.capterra.fr/reviews/211798/sketchup?countries[]=fr#facets?page=1
# categories_list:  20
# len:  4373
#  65%|██████████████████████████████████████████████████████████████████████                                      | 35/54 [2:58:37<22:17, 70.40s/it]
# webII:  https://www.capterra.fr/reviews/152433/hostaway?countries[]=fr#facets
# Npages:  1
# https://www.capterra.fr/reviews/152433/hostaway?countries[]=fr#facets?page=1
# categories_list:  10
# len:  4378
#  67%|████████████████████████████████████████████████████████████████████████                                    | 36/54 [2:59:00<16:55, 56.41s/it]
# webII:  https://www.capterra.fr/reviews/131924/lodgify?countries[]=fr#facets
# Npages:  2
# https://www.capterra.fr/reviews/131924/lodgify?countries[]=fr#facets?page=1
# categories_list:  25
# len:  4393
# https://www.capterra.fr/reviews/131924/lodgify?countries[]=fr#facets?page=2
# categories_list:  25
# len:  4408
#  69%|██████████████████████████████████████████████████████████████████████████                                  | 37/54 [3:00:19<17:51, 63.04s/it]
# webII:  https://www.capterra.fr/reviews/164283/zendesk?countries[]=fr#facets
# Npages:  3
# https://www.capterra.fr/reviews/164283/zendesk?countries[]=fr#facets?page=1
# categories_list:  25
# len:  4415
# https://www.capterra.fr/reviews/164283/zendesk?countries[]=fr#facets?page=2
# categories_list:  25
# len:  4422
# https://www.capterra.fr/reviews/164283/zendesk?countries[]=fr#facets?page=3
# categories_list:  25
# len:  4429
#  70%|████████████████████████████████████████████████████████████████████████████                                | 38/54 [3:02:14<20:57, 78.60s/it]
# webII:  https://www.capterra.fr/reviews/169505/zoho-desk?countries[]=fr#facets
# Npages:  2
# https://www.capterra.fr/reviews/169505/zoho-desk?countries[]=fr#facets?page=1
# categories_list:  25
# len:  4441
# https://www.capterra.fr/reviews/169505/zoho-desk?countries[]=fr#facets?page=2
# categories_list:  25
# len:  4453
#  72%|██████████████████████████████████████████████████████████████████████████████                              | 39/54 [3:03:32<19:36, 78.47s/it]
# webII:  https://www.capterra.fr/reviews/102188/liveagent?countries[]=fr#facets
# Npages:  1
# https://www.capterra.fr/reviews/102188/liveagent?countries[]=fr#facets?page=1
# categories_list:  23
# len:  4463
#  74%|████████████████████████████████████████████████████████████████████████████████                            | 40/54 [3:04:11<15:33, 66.69s/it]
# webII:  https://www.capterra.fr/reviews/135003/slack?countries[]=fr#facets
# Npages:  7
# https://www.capterra.fr/reviews/135003/slack?countries[]=fr#facets?page=1
# categories_list:  25
# len:  4475
# https://www.capterra.fr/reviews/135003/slack?countries[]=fr#facets?page=2
# categories_list:  25
# len:  4487
# https://www.capterra.fr/reviews/135003/slack?countries[]=fr#facets?page=3
# categories_list:  25
# len:  4499
# https://www.capterra.fr/reviews/135003/slack?countries[]=fr#facets?page=4
# categories_list:  25
# len:  4511
# https://www.capterra.fr/reviews/135003/slack?countries[]=fr#facets?page=5
# categories_list:  25
# len:  4523
# https://www.capterra.fr/reviews/135003/slack?countries[]=fr#facets?page=6
# categories_list:  25
# len:  4535
# https://www.capterra.fr/reviews/135003/slack?countries[]=fr#facets?page=7
# categories_list:  25
# len:  4547
#  76%|█████████████████████████████████████████████████████████████████████████████████▏                         | 41/54 [3:08:35<27:14, 125.72s/it]
# webII:  https://www.capterra.fr/reviews/180345/whatsapp?countries[]=fr#facets
# Npages:  4
# https://www.capterra.fr/reviews/180345/whatsapp?countries[]=fr#facets?page=1
# categories_list:  25
# len:  4559
# https://www.capterra.fr/reviews/180345/whatsapp?countries[]=fr#facets?page=2
# categories_list:  25
# len:  4571
# https://www.capterra.fr/reviews/180345/whatsapp?countries[]=fr#facets?page=3
# categories_list:  25
# len:  4583
# https://www.capterra.fr/reviews/180345/whatsapp?countries[]=fr#facets?page=4
# categories_list:  25
# len:  4595
#  78%|███████████████████████████████████████████████████████████████████████████████████▏                       | 42/54 [3:11:08<26:46, 133.90s/it]
# webII:  https://www.capterra.fr/reviews/124981/freshdesk?countries[]=fr#facets
# Npages:  2
# https://www.capterra.fr/reviews/124981/freshdesk?countries[]=fr#facets?page=1
# categories_list:  25
# len:  4607
# https://www.capterra.fr/reviews/124981/freshdesk?countries[]=fr#facets?page=2
# categories_list:  25
# len:  4619
#  80%|█████████████████████████████████████████████████████████████████████████████████████▏                     | 43/54 [3:12:27<21:31, 117.42s/it]
# webII:  https://www.capterra.fr/reviews/132666/pipedrive?countries[]=fr#facets
# Npages:  3
# https://www.capterra.fr/reviews/132666/pipedrive?countries[]=fr#facets?page=1
# categories_list:  25
# len:  4633
# https://www.capterra.fr/reviews/132666/pipedrive?countries[]=fr#facets?page=2
# categories_list:  25
# len:  4647
# https://www.capterra.fr/reviews/132666/pipedrive?countries[]=fr#facets?page=3
# categories_list:  25
# len:  4661
#  81%|███████████████████████████████████████████████████████████████████████████████████████▏                   | 44/54 [3:14:21<19:26, 116.63s/it]
# webII:  https://www.capterra.fr/reviews/62194/livechat?countries[]=fr#facets
# Npages:  1
# https://www.capterra.fr/reviews/62194/livechat?countries[]=fr#facets?page=1
# categories_list:  19
# len:  4671
#  83%|██████████████████████████████████████████████████████████████████████████████████████████                  | 45/54 [3:14:56<13:48, 92.04s/it]
# webII:  https://www.capterra.fr/reviews/134347/intercom?countries[]=fr#facets
# Npages:  1
# https://www.capterra.fr/reviews/134347/intercom?countries[]=fr#facets?page=1
# categories_list:  21
# len:  4679
#  85%|████████████████████████████████████████████████████████████████████████████████████████████                | 46/54 [3:15:33<10:04, 75.55s/it]
# webII:  https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets
# Npages:  25
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=1
# categories_list:  25
# len:  4698
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=2
# categories_list:  25
# len:  4717
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=3
# categories_list:  25
# len:  4736
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=4
# categories_list:  25
# len:  4755
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=5
# categories_list:  25
# len:  4774
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=6
# categories_list:  25
# len:  4793
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=7
# categories_list:  25
# len:  4812
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=8
# categories_list:  25
# len:  4831
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=9
# categories_list:  25
# len:  4850
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=10
# categories_list:  25
# len:  4869
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=11
# categories_list:  25
# len:  4888
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=12
# categories_list:  25
# len:  4907
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=13
# categories_list:  25
# len:  4926
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=14
# categories_list:  25
# len:  4945
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=15
# categories_list:  25
# len:  4964
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=16
# categories_list:  25
# len:  4983
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=17
# categories_list:  25
# len:  5002
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=18
# categories_list:  25
# len:  5021
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=19
# categories_list:  25
# len:  5040
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=20
# categories_list:  25
# len:  5059
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=21
# categories_list:  25
# len:  5078
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=22
# categories_list:  25
# len:  5097
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=23
# categories_list:  25
# len:  5116
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=24
# categories_list:  25
# len:  5135
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=25
# categories_list:  25
# len:  5154
#  87%|█████████████████████████████████████████████████████████████████████████████████████████████▏             | 47/54 [3:31:08<38:52, 333.20s/it]
# webII:  https://www.capterra.fr/reviews/132666/pipedrive?countries[]=fr#facets
# Npages:  3
# https://www.capterra.fr/reviews/132666/pipedrive?countries[]=fr#facets?page=1
# categories_list:  25
# len:  5168
# https://www.capterra.fr/reviews/132666/pipedrive?countries[]=fr#facets?page=2
# categories_list:  25
# len:  5182
# https://www.capterra.fr/reviews/132666/pipedrive?countries[]=fr#facets?page=3
# categories_list:  25
# len:  5196
#  89%|███████████████████████████████████████████████████████████████████████████████████████████████            | 48/54 [3:33:03<26:47, 267.98s/it]
# webII:  https://www.capterra.fr/reviews/140928/appy-pie?countries[]=fr#facets
# Npages:  1
# https://www.capterra.fr/reviews/140928/appy-pie?countries[]=fr#facets?page=1
# categories_list:  6
# len:  5200
#  91%|█████████████████████████████████████████████████████████████████████████████████████████████████          | 49/54 [3:33:23<16:07, 193.59s/it]
# webII:  https://www.capterra.fr/reviews/134347/intercom?countries[]=fr#facets
# Npages:  1
# https://www.capterra.fr/reviews/134347/intercom?countries[]=fr#facets?page=1
# categories_list:  21
# len:  5208
#  93%|███████████████████████████████████████████████████████████████████████████████████████████████████        | 50/54 [3:34:00<09:46, 146.64s/it]
# webII:  https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets
# Npages:  25
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=1
# categories_list:  25
# len:  5227
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=2
# categories_list:  25
# len:  5246
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=3
# categories_list:  25
# len:  5265
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=4
# categories_list:  25
# len:  5284
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=5
# categories_list:  25
# len:  5303
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=6
# categories_list:  25
# len:  5322
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=7
# categories_list:  25
# len:  5341
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=8
# categories_list:  25
# len:  5360
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=9
# categories_list:  25
# len:  5379
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=10
# categories_list:  25
# len:  5398
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=11
# categories_list:  25
# len:  5417
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=12
# categories_list:  25
# len:  5436
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=13
# categories_list:  25
# len:  5455
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=14
# categories_list:  25
# len:  5474
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=15
# categories_list:  25
# len:  5493
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=16
# categories_list:  25
# len:  5512
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=17
# categories_list:  25
# len:  5531
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=18
# categories_list:  25
# len:  5550
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=19
# categories_list:  25
# len:  5569
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=20
# categories_list:  25
# len:  5588
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=21
# categories_list:  25
# len:  5607
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=22
# categories_list:  25
# len:  5626
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=23
# categories_list:  25
# len:  5645
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=24
# categories_list:  25
# len:  5664
# https://www.capterra.fr/reviews/152997/birdeye?countries[]=fr#facets?page=25
# categories_list:  25
# len:  5683
#  94%|█████████████████████████████████████████████████████████████████████████████████████████████████████      | 51/54 [3:49:36<19:09, 383.30s/it]
# webII:  https://www.capterra.fr/reviews/128285/acuity-scheduling?countries[]=fr#facets
# Npages:  1
# https://www.capterra.fr/reviews/128285/acuity-scheduling?countries[]=fr#facets?page=1
# categories_list:  24
# len:  5695
#  96%|███████████████████████████████████████████████████████████████████████████████████████████████████████    | 52/54 [3:50:16<09:20, 280.45s/it]
# webII:  https://www.capterra.fr/reviews/153752/vagaro?countries[]=fr#facets
# Npages:  1
# https://www.capterra.fr/reviews/153752/vagaro?countries[]=fr#facets?page=1
# categories_list:  2
# len:  5696
#  98%|█████████████████████████████████████████████████████████████████████████████████████████████████████████  | 53/54 [3:50:32<03:20, 200.87s/it]
# webII:  https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets
# Npages:  49
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=1
# categories_list:  25
# len:  5718
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=2
# categories_list:  25
# len:  5740
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=3
# categories_list:  25
# len:  5762
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=4
# categories_list:  25
# len:  5784
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=5
# categories_list:  25
# len:  5806
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=6
# categories_list:  25
# len:  5828
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=7
# categories_list:  25
# len:  5850
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=8
# categories_list:  25
# len:  5872
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=9
# categories_list:  25
# len:  5894
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=10
# categories_list:  25
# len:  5916
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=11
# categories_list:  25
# len:  5938
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=12
# categories_list:  25
# len:  5960
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=13
# categories_list:  25
# len:  5982
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=14
# categories_list:  25
# len:  6004
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=15
# categories_list:  25
# len:  6026
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=16
# categories_list:  25
# len:  6048
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=17
# categories_list:  25
# len:  6070
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=18
# categories_list:  25
# len:  6092
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=19
# categories_list:  25
# len:  6114
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=20
# categories_list:  25
# len:  6136
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=21
# categories_list:  25
# len:  6158
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=22
# categories_list:  25
# len:  6180
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=23
# categories_list:  25
# len:  6202
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=24
# categories_list:  25
# len:  6224
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=25
# categories_list:  25
# len:  6246
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=26
# categories_list:  25
# len:  6268
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=27
# categories_list:  25
# len:  6290
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=28
# categories_list:  25
# len:  6312
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=29
# categories_list:  25
# len:  6334
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=30
# categories_list:  25
# len:  6356
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=31
# categories_list:  25
# len:  6378
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=32
# categories_list:  25
# len:  6400
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=33
# categories_list:  25
# len:  6422
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=34
# categories_list:  25
# len:  6444
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=35
# categories_list:  25
# len:  6466
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=36
# categories_list:  25
# len:  6488
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=37
# categories_list:  25
# len:  6510
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=38
# categories_list:  25
# len:  6532
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=39
# categories_list:  25
# len:  6554
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=40
# categories_list:  25
# len:  6576
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=41
# categories_list:  25
# len:  6598
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=42
# categories_list:  25
# len:  6620
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=43
# categories_list:  25
# len:  6642
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=44
# categories_list:  25
# len:  6664
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=45
# categories_list:  25
# len:  6686
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=46
# categories_list:  25
# len:  6708
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=47
# categories_list:  25
# len:  6730
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=48
# categories_list:  25
# len:  6752
# https://www.capterra.fr/reviews/129169/tebra?countries[]=fr#facets?page=49
# categories_list:  25
# len:  6774
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████| 54/54 [4:21:01<00:00, 290.03s/it]

# %%
import pandas as pd
filename = str(start)+"_"+str(end)+".csv"
df = pd.DataFrame(records)
df.to_csv("../data_csv/"+filename, index=False)
